# %%
import numpy as np
import matplotlib.pyplot as plt

from SALib.sample import saltelli
from SALib.analyze import sobol
from math import *
from dolfin import *
import numpy as np
import matplotlib.pyplot as plt
from SALib.sample import saltelli
from SALib.analyze import sobol

# %% [markdown]
# # Example 1: Sensitivity analysis in a range

# %% [markdown]
# Creating example inputs and outputs in a range

# %%
def parabola(x, a, b):
    """Return y = a + b*x**2."""
    return a + b*x**2
problem = {
    'num_vars': 2,
    'names': ['a', 'b'],
    'bounds': [[0, 1]]*2
}

# sample
param_values = saltelli.sample(problem, 2**6)

# evaluate
x = np.linspace(-1, 1, 100)
y = np.array([parabola(x, *params) for params in param_values])

# analyse
sobol_indices = [sobol.analyze(problem, Y) for Y in y.T]
S1s = np.array([s['S1'] for s in sobol_indices])

# %% [markdown]
# Visualising the example by plotting graphs

# %%
fig = plt.figure(figsize=(10, 6), constrained_layout=True)
gs = fig.add_gridspec(2, 2)

ax0 = fig.add_subplot(gs[:, 0])
ax1 = fig.add_subplot(gs[0, 1])
ax2 = fig.add_subplot(gs[1, 1])

for i, ax in enumerate([ax1, ax2]):
    ax.plot(x, S1s[:, i],
            label=r'S1$_\mathregular{{{}}}$'.format(problem["names"][i]),
            color='black')
    ax.set_xlabel("x")
    ax.set_ylabel("First-order Sobol index")

    ax.set_ylim(0, 1.04)

    ax.yaxis.set_label_position("right")
    ax.yaxis.tick_right()

    ax.legend(loc='upper right')

ax0.plot(x, np.mean(y, axis=0), label="Mean", color='black')

# in percent
prediction_interval = 95

ax0.fill_between(x,
                 np.percentile(y, 50 - prediction_interval/2., axis=0),
                 np.percentile(y, 50 + prediction_interval/2., axis=0),
                 alpha=0.5, color='black',
                 label=f"{prediction_interval} % prediction interval")

ax0.set_xlabel("x")
ax0.set_ylabel("y")
ax0.legend(title=r"$y=a+b\cdot x^2$",
           loc='upper center')._legend_box.align = "left"

plt.show()

# %% [markdown]
# First order, second order and total order sensitivity indices and minimum and maximum values of result

# %%
S1s = np.array([s['S1'] for s in sobol_indices])
S2s = np.array([s['S2'] for s in sobol_indices])
Sts = np.array([s['ST'] for s in sobol_indices])
print("First order indices")
print(S1s)
print("Second order indices")
print(S2s)
print("Total order indices")
print(Sts)

print("min:",min(map(min, y)))
print("max",max(map(max, y)))
# Out:
# First order indices
# [[ 4.95265841e-01  4.95265841e-01]
#  [ 5.15563712e-01  4.75005519e-01]
#  [ 5.36223732e-01  4.54399826e-01]
#  [ 5.57187473e-01  4.33507928e-01]
#  [ 5.78389892e-01  4.12395501e-01]
#  [ 5.99759734e-01  3.91134309e-01]
#  [ 6.21220112e-01  3.69801603e-01]
#  [ 6.42689282e-01  3.48479335e-01]
#  [ 6.64081600e-01  3.27253178e-01]
#  [ 6.85308651e-01  3.06211390e-01]
#  [ 7.06280525e-01  2.85443525e-01]
#  [ 7.26907217e-01  2.65039034e-01]
#  [ 7.47100096e-01  2.45085790e-01]
#  [ 7.66773414e-01  2.25668587e-01]
#  [ 7.85845796e-01  2.06867658e-01]
#  [ 8.97196254e-01  9.77200212e-02]
#  [ 8.83982076e-01  1.10599120e-01]
#  [ 8.69818959e-01  1.24430920e-01]
#  [ 8.54727327e-01  1.39196857e-01]
#  [ 8.38738101e-01  1.54867849e-01]
#  [ 8.21892513e-01  1.71404450e-01]
#  [ 8.04241659e-01  1.88757272e-01]
#  [ 7.85845796e-01  2.06867658e-01]
#  [ 7.66773414e-01  2.25668587e-01]
#  [ 7.47100096e-01  2.45085790e-01]
#  [ 7.26907217e-01  2.65039034e-01]
#  [ 7.06280525e-01  2.85443525e-01]
#  [ 6.85308651e-01  3.06211390e-01]
#  [ 6.64081600e-01  3.27253178e-01]
#  [ 6.42689282e-01  3.48479335e-01]
#  [ 6.21220112e-01  3.69801603e-01]
#  [ 5.99759734e-01  3.91134309e-01]
#  [ 5.78389892e-01  4.12395501e-01]
#  [ 5.57187473e-01  4.33507928e-01]
#  [ 5.36223732e-01  4.54399826e-01]
#  [ 5.15563712e-01  4.75005519e-01]
#  [ 4.95265841e-01  4.95265841e-01]]
# Second order indices
# [[[           nan 4.36999272e-03]
#   [           nan            nan]]
#
#  [[           nan 4.36637602e-03]
#   [           nan            nan]]
#
#  [[           nan 4.35525428e-03]
#   [           nan            nan]]
#
#  [[           nan 4.33624730e-03]
#   [           nan            nan]]
#
#  [[           nan 4.30901874e-03]
#   [           nan            nan]]
#
#  [[           nan 4.27328540e-03]
#   [           nan            nan]]
#
#  [[           nan 4.22882628e-03]
#   [           nan            nan]]
#
#  [[           nan 4.17549112e-03]
#   [           nan            nan]]
#
#  [[           nan 4.11320812e-03]
#   [           nan            nan]]
#
#  [[           nan 4.04199035e-03]
#   [           nan            nan]]
#
#  [[           nan 3.96194071e-03]
#   [           nan            nan]]
#
#  [[           nan 3.87325507e-03]
#   [           nan            nan]]
#
#  [[           nan 3.77622327e-03]
#   [           nan            nan]]
#
#  [[           nan 3.67122802e-03]
#   [           nan            nan]]
#
#  [[           nan 3.55874147e-03]
#   [           nan            nan]]
#
#  [[           nan 3.43931962e-03]
#   [           nan            nan]]
#
#  [[           nan 3.31359458e-03]
#   [           nan            nan]]
#
#  [[           nan 3.18226501e-03]
#   [           nan            nan]]
#
#  [[           nan 3.04608507e-03]
#   [           nan            nan]]
#
#  [[           nan 2.90585224e-03]
#   [           nan            nan]]
#
#  [[           nan 2.76239439e-03]
#   [           nan            nan]]
#
#  [[           nan 2.61655665e-03]
#   [           nan            nan]]
#
#  [[           nan 2.46918849e-03]
#   [           nan            nan]]
#
#  [[           nan 2.32113142e-03]
#   [           nan            nan]]
#
#  [[           nan 2.17320758e-03]
#   [           nan            nan]]
#
#  [[           nan 2.02620971e-03]
#   [           nan            nan]]
#
#  [[           nan 1.88089249e-03]
#   [           nan            nan]]
#
#  [[           nan 1.73796555e-03]
#   [           nan            nan]]
#
#  [[           nan 1.59808811e-03]
#   [           nan            nan]]
#
#  [[           nan 1.46186530e-03]
#   [           nan            nan]]
#
#  [[           nan 1.32984601e-03]
#   [           nan            nan]]
#
#  [[           nan 1.20252220e-03]
#   [           nan            nan]]
#
#  [[           nan 1.08032953e-03]
#   [           nan            nan]]
#
#  [[           nan 9.63649018e-04]
#   [           nan            nan]]
#
#  [[           nan 8.52809644e-04]
#   [           nan            nan]]
#
#  [[           nan 7.48091683e-04]
#   [           nan            nan]]
#
#  [[           nan 6.49730517e-04]
#   [           nan            nan]]
#
#  [[           nan 5.57920812e-04]
#   [           nan            nan]]
#
#  [[           nan 4.72820885e-04]
#   [           nan            nan]]
#
#  [[           nan 3.94557120e-04]
#   [           nan            nan]]
#
#  [[           nan 3.23228320e-04]
#   [           nan            nan]]
#
#  [[           nan 2.58909899e-04]
#   [           nan            nan]]
#
#  [[           nan 2.01657842e-04]
#   [           nan            nan]]
#
#  [[           nan 1.51512359e-04]
#   [           nan            nan]]
#
#  [[           nan 1.08501203e-04]
#   [           nan            nan]]
#
#  [[           nan 7.26426194e-05]
#   [           nan            nan]]
#
#  [[           nan 4.39478852e-05]
#   [           nan            nan]]
#
#  [[           nan 2.24234485e-05]
#   [           nan            nan]]
#
#  [[           nan 8.07264165e-06]
#   [           nan            nan]]
#
#  [[           nan 8.96969512e-07]
#   [           nan            nan]]
#
#  [[           nan 8.96969512e-07]
#   [           nan            nan]]
#
#  [[           nan 8.07264165e-06]
#   [           nan            nan]]
#
#  [[           nan 2.24234485e-05]
#   [           nan            nan]]
#
#  [[           nan 4.39478852e-05]
#   [           nan            nan]]
#
#  [[           nan 7.26426194e-05]
#   [           nan            nan]]
#
#  [[           nan 1.08501203e-04]
#   [           nan            nan]]
#
#  [[           nan 1.51512359e-04]
#   [           nan            nan]]
#
#  [[           nan 2.01657842e-04]
#   [           nan            nan]]
#
#  [[           nan 2.58909899e-04]
#   [           nan            nan]]
#
#  [[           nan 3.23228320e-04]
#   [           nan            nan]]
#
#  [[           nan 3.94557120e-04]
#   [           nan            nan]]
#
#  [[           nan 4.72820885e-04]
#   [           nan            nan]]
#
#  [[           nan 5.57920812e-04]
#   [           nan            nan]]
#
#  [[           nan 6.49730517e-04]
#   [           nan            nan]]
#
#  [[           nan 7.48091683e-04]
#   [           nan            nan]]
#
#  [[           nan 8.52809644e-04]
#   [           nan            nan]]
#
#  [[           nan 9.63649018e-04]
#   [           nan            nan]]
#
#  [[           nan 1.08032953e-03]
#   [           nan            nan]]
#
#  [[           nan 1.20252220e-03]
#   [           nan            nan]]
#
#  [[           nan 1.32984601e-03]
#   [           nan            nan]]
#
#  [[           nan 1.46186530e-03]
#   [           nan            nan]]
#
#  [[           nan 1.59808811e-03]
#   [           nan            nan]]
#
#  [[           nan 1.73796555e-03]
#   [           nan            nan]]
#
#  [[           nan 1.88089249e-03]
#   [           nan            nan]]
#
#  [[           nan 2.02620971e-03]
#   [           nan            nan]]
#
#  [[           nan 2.17320758e-03]
#   [           nan            nan]]
#
#  [[           nan 2.32113142e-03]
#   [           nan            nan]]
#
#  [[           nan 2.46918849e-03]
#   [           nan            nan]]
#
#  [[           nan 2.61655665e-03]
#  [9.97196676e-01 2.90078178e-03]
#  [9.98185227e-01 2.01795376e-03]
#  [9.98946076e-01 1.35325407e-03]
#  [9.99518083e-01 8.67779195e-04]
#  [9.99936544e-01 5.26211541e-04]
#  [1.00023304e+00 2.96959688e-04]
#  [1.00043534e+00 1.52258890e-04]
#  [1.00056733e+00 6.82400364e-05]
#  [1.00064895e+00 2.49744997e-05]
#  [1.00069617e+00 6.50137396e-06]
#  [1.00072099e+00 8.42598960e-07]
#  [1.00073139e+00 1.04025645e-08]
#  [1.00073139e+00 1.04025645e-08]
#  [1.00072099e+00 8.42598960e-07]
#  [1.00069617e+00 6.50137396e-06]
#  [1.00064895e+00 2.49744997e-05]
#  [1.00056733e+00 6.82400364e-05]
#  [1.00043534e+00 1.52258890e-04]
#  [1.00023304e+00 2.96959688e-04]
#  [9.99936544e-01 5.26211541e-04]
#  [9.99518083e-01 8.67779195e-04]
#  [9.98946076e-01 1.35325407e-03]
#  [9.98185227e-01 2.01795376e-03]
#  [9.97196676e-01 2.90078178e-03]
#  [9.95938193e-01 4.04403881e-03]
#  [9.94364428e-01 5.49317619e-03]
#  [9.92427233e-01 7.29648270e-03]
#  [9.90076056e-01 9.50469588e-03]
#  [9.87258419e-01 1.21705302e-02]
#  [9.83920486e-01 1.53481160e-02]
#  [9.80007723e-01 1.90923456e-02]
#  [9.75465652e-01 2.34581253e-02]
#  [9.70240694e-01 2.84995370e-02]
#  [9.64281092e-01 3.42689159e-02]
#  [9.57537911e-01 4.08158575e-02]
#  [9.49966081e-01 4.81861716e-02]
#  [9.41525474e-01 5.64208062e-02]
#  [9.32181976e-01 6.55547701e-02]
#  [9.21908530e-01 7.56160878e-02]
#  [9.10686099e-01 8.66248226e-02]
#  [8.98504533e-01 9.85922068e-02]
#  [8.85363273e-01 1.11519918e-01]
#  [8.71271885e-01 1.25399537e-01]
#  [8.56250370e-01 1.40212219e-01]
#  [8.40329234e-01 1.55928604e-01]
#  [8.23549311e-01 1.72508982e-01]
#  [8.05961318e-01 1.89903712e-01]
#  [7.87625166e-01 2.08053905e-01]
#  [7.68609028e-01 2.26892330e-01]
#  [7.48988207e-01 2.46344531e-01]
#  [7.28843845e-01 2.66330119e-01]
#  [7.08261496e-01 2.86764172e-01]
#  [6.87329646e-01 3.07558720e-01]
#  [6.66138205e-01 3.28624247e-01]
#  [6.44777028e-01 3.49871165e-01]
#  [6.23334525e-01 3.71211212e-01]
#  [6.01896376e-01 3.92558737e-01]
#  [5.80544401e-01 4.13831841e-01]
#  [5.59355596e-01 4.34953344e-01]
#  [5.38401360e-01 4.55851577e-01]
#  [5.17746900e-01 4.76460977e-01]
#  [4.97450838e-01 4.96722505e-01]]
# min: 0.007877066115702479
# max 1.984375

# %% [markdown]
# # Example 2: Sensitivity analysis in a range

# %%
def prob(x,e1,h):
    for i in x:
        L = i
        H = h
        Nx = 250
        Ny = 10
        mesh = RectangleMesh(Point(0., 0.), Point(L, H), Nx, Ny, "crossed")

        def eps(v):
            return sym(grad(v)  )

        E = Constant(e1)
        nu = Constant(.3)
        model = "plane_stress"

        mu = E/2/(1+nu)
        lmbda = E*nu/(1+nu)/(1-2*nu)
        if model == "plane_stress":
            lmbda = 2*mu*lmbda/(lmbda+2*mu)

        def sigma(v):
            return lmbda*tr(eps(v))*Identity(2) + 2.0*mu*eps(v)

        rho_g = 1e-3
        f = Constant((0, -rho_g))

        V = VectorFunctionSpace(mesh, 'Lagrange', degree=2)
        du = TrialFunction(V)
        u_ = TestFunction(V)
        a = inner(sigma(du), eps(u_))*dx
        l = inner(f, u_)*dx
        def left(x, on_boundary):
            return near(x[0], 0.)

        bc = DirichletBC(V, Constant((0.,0.)), left)

        u = Function(V, name="Displacement")
        solve(a == l, u, bc)

        #plot(1e3*u, mode="displacement")
        # print("Maximal deflection:", -u(L,H/2.)[1])
        # print("Beam theory deflection:", float(3*rho_g*L**4/2/E/H**3))
        Vsig = TensorFunctionSpace(mesh, "DG", degree=0)
        sig = Function(Vsig, name="Stress")
        sig.assign(project(sigma(u), Vsig))
        #print("Stress at (0,H):", sig(0, H))

        # file_results = XDMFFile("elasticity_results.xdmf")
        # file_results.parameters["flush_output"] = True
        # file_results.parameters["functions_share_mesh"] = True
        # file_results.write(u, 0.)
        # file_results.write(sig, 0.)
        return -u(L,H/2.)[1]+(x-x)

# %% [markdown]
# Creating variables and range

# %%
problem = {
    'num_vars': 2,
    'names': ['E','H'],
    'bounds': [[100000-1000, 100000+1000],[.98,1.02]]
}
param_values = saltelli.sample(problem, 2**4)
x = np.linspace(24,26,5)
y = np.array([prob(x, *params) for params in param_values])

# %%
sobol_indices = [sobol.analyze(problem, Y) for Y in y.T]
S1s = np.array([s['S1'] for s in sobol_indices])

# %% [markdown]
# Sensitivity indices and maximum and minimum outputs

# %%
fig = plt.figure(figsize=(10, 6), constrained_layout=True)
gs = fig.add_gridspec(2, 2)
ax0 = fig.add_subplot(gs[:, 0])
ax1 = fig.add_subplot(gs[0, 1])
ax2 = fig.add_subplot(gs[1, 1])

for i, ax in enumerate([ax1, ax2]):
    ax.plot(x, S1s[:, i],
            label=r'S1$_\mathregular{{{}}}$'.format(problem["names"][i]),
            color='black')
    ax.set_xlabel("x")
    ax.set_ylabel("First-order Sobol index")

    ax.set_ylim(-1, 2)

    ax.yaxis.set_label_position("right")
    ax.yaxis.tick_right()

    ax.legend(loc='upper right')

ax0.plot(x, np.mean(y, axis=0), label="Mean", color='black')

# in percent
prediction_interval = 95

ax0.fill_between(x,
                 np.percentile(y, 50 - prediction_interval/2., axis=0),
                 np.percentile(y, 50 + prediction_interval/2., axis=0),
                 alpha=0.5, color='black',
                 label=f"{prediction_interval} % prediction interval")

ax0.set_xlabel("x")
ax0.set_ylabel("y")


plt.show()

# %%
S1s = np.array([s['S1'] for s in sobol_indices])
S2s = np.array([s['S2'] for s in sobol_indices])
Sts = np.array([s['ST'] for s in sobol_indices])
print("First order indices")
print(S1s)
print("Second order indices")
print(S2s)
print("Total order indices")
print(Sts)

print("min:",min(map(min, y)))
print("max",max(map(max, y)))
# Out:
# First order indices
# [[0.08208289 1.11858759]
#  [0.08208289 1.11858759]
#  [0.08208289 1.11858759]
#  [0.08208289 1.11858759]
#  [0.08208289 1.11858759]]
# Second order indices
# [[[        nan -0.04589341]
#   [        nan         nan]]
#
#  [[        nan -0.04589341]
#   [        nan         nan]]
#
#  [[        nan -0.04589341]
#   [        nan         nan]]
#
#  [[        nan -0.04589341]
#   [        nan         nan]]
#
#  [[        nan -0.04589341]
#   [        nan         nan]]]
# Total order indices
# [[0.06039652 1.11316328]
#  [0.06039652 1.11316328]
#  [0.06039652 1.11316328]
#  [0.06039652 1.11316328]
#  [0.06039652 1.11316328]]
# min: 0.004754887012543375
# max 0.005182509740232491

# %% [markdown]
# # Example 3: Sensitivity analysis at a point

# %%
def parabola(x, a, b, c):
    return sin(a) + 100 * sin(b) ** 2 + c**4 * sin(a) + x - x
problem = {
    'num_vars': 3,
    'names': ['a', 'b', 'c'],
    'bounds': [[-3.14159265359,3.14159265359],[-3.14159265359,3.14159265359],[-3.14159265359,3.14159265359]]
}

# sample
param_values = saltelli.sample(problem, 2**15)

# evaluate
x = np.array([1])
y = np.array([parabola(x, *params) for params in param_values])

# analyse
sobol_indices = [sobol.analyze(problem, Y) for Y in y.T]
S1s = np.array([s['S1'] for s in sobol_indices])

# %% [markdown]
# Sensitivity indices and maximum and minimum outputs

# %%
S1s = np.array([s['S1'] for s in sobol_indices])
S2s = np.array([s['S2'] for s in sobol_indices])
Sts = np.array([s['ST'] for s in sobol_indices])
print("First order indices")
print(S1s)
print("Second order indices")
print(S2s)
print("Total order indices")
print(Sts)

print("min:",min(map(min, y)))
print("max",max(map(max, y)))
# Out:
# First order indices
# [[ 1.16095388e-01  6.95548647e-01 -6.14231311e-04]]
# Second order indices
# [[[           nan 3.74783246e-06 1.88352356e-01]
#   [           nan            nan 3.26279736e-06]
#   [           nan            nan            nan]]]
# Total order indices
# [[0.30411956 0.69555245 0.18773846]]
# min: -96.98259836111642
# max 198.20700614027368

# %% [markdown]
# # Example 4: Sensitivity analysis at a point

# %%
problem = {
    'num_vars': 2,
    'names': ['E','H'],
    'bounds': [[100000-1000, 100000+1000],[.98,1.02]]
}
param_values = saltelli.sample(problem, 2**6)
x = np.array([25])
y = np.array([prob(x, *params) for params in param_values])

# %%
sobol_indices = [sobol.analyze(problem, Y) for Y in y.T]

# %% [markdown]
# Sensitivity indices and maximum and minimum outputs

# %%
S1s = np.array([s['S1'] for s in sobol_indices])
S2s = np.array([s['S2'] for s in sobol_indices])
Sts = np.array([s['ST'] for s in sobol_indices])
print("First order indices")
print(S1s)
print("Second order indices")
print(S2s)
print("Total order indices")
print(Sts)

print("min:",min(map(min, y)))
print("max",max(map(max, y)))
# Out:
# First order indices
# [[0.05770262 0.9366997 ]]
# Second order indices
# [[[       nan 0.00246324]
#   [       nan        nan]]]
# Total order indices
# [[0.05879616 0.93751445]]
# min: 0.005584810433480647
# max 0.006134726490689045
